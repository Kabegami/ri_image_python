# %%
from imageNetParser import *
from index import *

# %%
def foreach(f, it):
    for e in it:
        f(e)
        
def foreachp(f, it):
    for e in it:
        print(f(e))

# %%
classe = "tree-frog"
frog = get_features("../data/{}.txt".format(classe))

# %%
im1 = frog[0]
im1.xs, im1.ys, im1.id
# Out:
# ([0.02500000037252903,
#   0.058333300054073334,
#   0.09166669845581055,
#   0.125,
#   0.15833300352096558,
#   0.19166700541973114,
#   0.22499999403953552,
#   0.2583329975605011,
#   0.29166701436042786,
#   0.32499998807907104,
#   0.3583329916000366,
#   0.3916670083999634,
#   0.42500001192092896,
#   0.45833298563957214,
#   0.4916670024394989,
#   0.5249999761581421,
#   0.5583329796791077,
#   0.5916669964790344,
#   0.625,
#   0.6583330035209656,
#   0.6916670203208923,
#   0.7250000238418579,
#   0.7583330273628235,
#   0.7916669845581055,
#   0.824999988079071,
#   0.8583329916000366,
#   0.8916670083999634,
#   0.925000011920929,
#   0.9583330154418945,
#   0.02500000037252903,
#   0.058333300054073334,
#   0.09166669845581055,
#   0.125,
#   0.15833300352096558,
#   0.19166700541973114,
#   0.22499999403953552,
#   0.2583329975605011,
#   0.29166701436042786,
#   0.32499998807907104,
#   0.3583329916000366,
#   0.3916670083999634,
#   0.42500001192092896,
# ...

# %%
exemple_img = list(filter(lambda x : "n01644373_354" in x.id,  frog))

# %%
foreachp(lambda x : x.id, exemple_img)
frog_exemple = exemple_img[0]
# Out:
# n01644373_354
#
# n01644373_3540

# %%
frog_exemple.wordsim
# Out:
# [196,
#  624,
#  398,
#  419,
#  102,
#  413,
#  221,
#  170,
#  221,
#  778,
#  379,
#  418,
#  187,
#  392,
#  567,
#  607,
#  897,
#  886,
#  736,
#  675,
#  168,
#  304,
#  196,
#  638,
#  576,
#  140,
#  140,
#  185,
#  616,
#  616,
#  616,
#  616,
#  846,
#  168,
#  368,
#  25,
#  8,
#  82,
#  251,
#  227,
#  980,
#  376,
#  251,
#  815,
#  522,
#  817,
#  368,
#  552,
#  552,
#  834,
#  879,
#  828,
#  681,
#  681,
#  663,
#  663,
#  635,
#  635,
#  36,
#  36,
#  12,
#  934,
#  190,
#  756,
#  461,
#  348,
#  548,
#  190,
#  947,
#  272,
#  795,
#  213,
#  870,
#  348,
#  635,
#  610,
#  635,
#  566,
#  720,
#  720,
#  720,
#  817,
#  885,
#  456,
#  373,
#  431,
#  804,
#  347,
#  649,
#  526,
#  418,
#  418,
#  696,
#  945,
#  196,
#  540,
#  409,
#  822,
#  817,
#  834,
#  736,
#  869,
#  869,
#  869,
#  869,
#  879,
#  138,
#  595,
#  727,
#  148,
#  4,
#  79,
#  627,
#  627,
#  627,
#  549,
#  221,
#  94,
#  608,
#  650,
#  440,
#  980,
#  40,
#  348,
#  898,
#  898,
# ...

# %%
bow = compute_bow(frog_exemple)

# %%
plot_histo(bow)
